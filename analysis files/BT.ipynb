# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import torchvision
from torchvision import transforms, datasets
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import os
from efficientnet_pytorch import EfficientNet

# %%
# Check for GPU availability
print(torch.cuda.is_available())  # Should return True
print(torch.cuda.current_device())  # Should return 0
print(torch.cuda.get_device_name(0))  # Should print "NVIDIA GeForce RTX 3050 Laptop GPU
# Out:
# True
# 0
# NVIDIA GeForce RTX 3050 Laptop GPU

# %%
# Define constants
IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 32  # Reduce to 16 or 8 if GPU memory issues occur
EPOCHS = 50
NUM_CLASSES = 4  # Matches your 4 classes
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Define the model with EfficientNet-B0
class BrainTumorClassifier(nn.Module):
    def __init__(self, num_classes):
        super(BrainTumorClassifier, self).__init__()
        # Load pretrained EfficientNet-B0
        self.base_model = EfficientNet.from_pretrained('efficientnet-b0')
        # Freeze base model parameters
        for param in self.base_model.parameters():
            param.requires_grad = False
        # Modify the classifier
        num_features = self.base_model._fc.in_features
        self.base_model._fc = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(num_features, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )
    
    def forward(self, x):
        return self.base_model(x)

# %%
# Data preprocessing and augmentation
def create_data_loaders(train_dir, val_dir):
    train_transforms = transforms.Compose([
        transforms.Resize((IMG_HEIGHT, IMG_WIDTH)),
        transforms.RandomRotation(20),
        transforms.RandomHorizontalFlip(),
        transforms.RandomAffine(degrees=0, translate=(0.2, 0.2)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    val_transforms = transforms.Compose([
        transforms.Resize((IMG_HEIGHT, IMG_WIDTH)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    train_dataset = datasets.ImageFolder(train_dir, transform=train_transforms)
    val_dataset = datasets.ImageFolder(val_dir, transform=val_transforms)
    
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
    
    return train_loader, val_loader, train_dataset.classes

# %%
# Training function
def train_model(model, train_loader, val_loader):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}
    
    for epoch in range(EPOCHS):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        
        train_loss = running_loss / len(train_loader)
        train_acc = 100 * correct / total
        
        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0
        
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        
        val_loss = val_loss / len(val_loader)
        val_acc = 100 * correct / total
        
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)
        
        print(f'Epoch {epoch+1}/{EPOCHS}:')
        print(f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%')
        print(f'Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%')
    
    return history

# %%
# Plotting function
def plot_training_history(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    ax1.plot(history['train_acc'], label='Training Accuracy')
    ax1.plot(history['val_acc'], label='Validation Accuracy')
    ax1.set_title('Model Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy (%)')
    ax1.legend()
    
    ax2.plot(history['train_loss'], label='Training Loss')
    ax2.plot(history['val_loss'], label='Validation Loss')
    ax2.set_title('Model Loss')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend()
    
    plt.tight_layout()
    plt.show()

# %%
# Evaluation function
def evaluate_model(model, val_loader, class_names):
    model.eval()
    y_true = []
    y_pred = []
    
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())
    
    print("\nClassification Report:")
    print(classification_report(y_true, y_pred, target_names=class_names))
    
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

# %%
# Test a single image
def test_single_image(model_path, image_path, class_names):
    model = BrainTumorClassifier(num_classes=NUM_CLASSES)
    model.load_state_dict(torch.load(model_path))
    model.to(DEVICE)
    model.eval()

    transform = transforms.Compose([
        transforms.Resize((IMG_HEIGHT, IMG_WIDTH)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    from PIL import Image
    image = Image.open(image_path).convert('RGB')
    image = transform(image).unsqueeze(0).to(DEVICE)

    with torch.no_grad():
        output = model(image)
        probabilities = torch.softmax(output, dim=1)[0]
        predicted_class = torch.argmax(probabilities).item()

    print("\nPrediction Results:")
    print(f"Predicted Class: {class_names[predicted_class]}")
    print("Probabilities:")
    for i, prob in enumerate(probabilities):
        print(f"{class_names[i]}: {prob:.4f}")

# %%
# Test multiple images
def test_multiple_images(model_path, test_dir, class_names):
    model = BrainTumorClassifier(num_classes=NUM_CLASSES)
    model.load_state_dict(torch.load(model_path))
    model.to(DEVICE)
    model.eval()

    test_loader, _, _ = create_data_loaders(test_dir, test_dir)
    evaluate_model(model, test_loader, class_names)

# %%
# Main execution
def main():
    # Define paths (update these to your actual dataset paths)
    train_dir = r"C:\Users\viraj\Documents\Virajs Projects\BT DETECTION\Training"  # Replace with your actual path
    val_dir = r"C:\Users\viraj\Documents\Virajs Projects\BT DETECTION\Testing"     # Replace with your actual path
    model_path = 'brain_tumor_classifier_efficient_net.pth'
    class_names = ['glioma', 'meningioma', 'pituitary', 'no_tumor']

    # Create data loaders
    train_loader, val_loader, class_names = create_data_loaders(train_dir, val_dir)

    # Initialize and train the model
    model = BrainTumorClassifier(num_classes=NUM_CLASSES)
    model.to(DEVICE)
    print(f"Using device: {DEVICE}")
    history = train_model(model, train_loader, val_loader)

    # Save the model
    torch.save(model.state_dict(), model_path)

    # Plot training history
    plot_training_history(history)

    # Evaluate the model
    evaluate_model(model, val_loader, class_names)

    # Testing mode
    test_mode = input("Enter 'single' to test one image or 'batch' to test multiple: ").lower()
    if test_mode == 'single':
        image_path = input("Enter the path to your test image: ")
        test_single_image(model_path, image_path, class_names)
    elif test_mode == 'batch':
        test_dir = input("Enter the path to your test directory: ")
        test_multiple_images(model_path, test_dir, class_names)
    else:
        print("Invalid mode selected. Please choose 'single' or 'batch'")

if __name__ == "__main__":
    main()
# Out:
# Loaded pretrained weights for efficientnet-b0
# Using device: cuda
# Epoch 1/50:
# Train Loss: 0.5894, Train Acc: 77.18%
# Val Loss: 0.5563, Val Acc: 80.06%
# Epoch 2/50:
# Train Loss: 0.4697, Train Acc: 81.90%
# Val Loss: 0.4435, Val Acc: 83.03%
# Epoch 3/50:
# Train Loss: 0.4425, Train Acc: 82.74%
# Val Loss: 0.4422, Val Acc: 83.98%
# Epoch 4/50:
# Train Loss: 0.4264, Train Acc: 83.43%
# Val Loss: 0.4494, Val Acc: 84.15%
# Epoch 5/50:
# Train Loss: 0.4237, Train Acc: 83.47%
# Val Loss: 0.4131, Val Acc: 84.93%
# Epoch 6/50:
# Train Loss: 0.4248, Train Acc: 83.57%
# Val Loss: 0.4057, Val Acc: 85.66%
# Epoch 7/50:
# Train Loss: 0.4048, Train Acc: 84.11%
# Val Loss: 0.3952, Val Acc: 85.21%
# Epoch 8/50:
# Train Loss: 0.3985, Train Acc: 84.43%
# Val Loss: 0.3864, Val Acc: 86.50%
# Epoch 9/50:
# Train Loss: 0.4054, Train Acc: 84.31%
# Val Loss: 0.3840, Val Acc: 86.11%
# Epoch 10/50:
# Train Loss: 0.3957, Train Acc: 84.84%
# Val Loss: 0.3959, Val Acc: 85.60%
# Epoch 11/50:
# Train Loss: 0.3893, Train Acc: 85.29%
# Val Loss: 0.3798, Val Acc: 85.99%
# Epoch 12/50:
# Train Loss: 0.3917, Train Acc: 84.66%
# Val Loss: 0.3776, Val Acc: 85.60%
# Epoch 13/50:
# Val Loss: 0.3427, Val Acc: 87.56%
# Epoch 39/50:
# Train Loss: 0.3553, Train Acc: 86.45%
# Val Loss: 0.3447, Val Acc: 87.23%
# Epoch 40/50:
# Train Loss: 0.3583, Train Acc: 86.17%
# Val Loss: 0.3386, Val Acc: 87.23%
# Epoch 41/50:
# Train Loss: 0.3562, Train Acc: 86.21%
# Val Loss: 0.3266, Val Acc: 88.01%
# Epoch 42/50:
# Train Loss: 0.3622, Train Acc: 85.98%
# Val Loss: 0.3358, Val Acc: 87.62%
# Epoch 43/50:
# Train Loss: 0.3622, Train Acc: 85.99%
# Val Loss: 0.3400, Val Acc: 87.51%
# Epoch 44/50:
# Train Loss: 0.3563, Train Acc: 86.40%
# Val Loss: 0.3384, Val Acc: 87.56%
# Epoch 45/50:
# Train Loss: 0.3562, Train Acc: 85.89%
# Val Loss: 0.3281, Val Acc: 87.62%
# Epoch 46/50:
# Train Loss: 0.3594, Train Acc: 86.28%
# Val Loss: 0.3294, Val Acc: 87.39%
# Epoch 47/50:
# Train Loss: 0.3556, Train Acc: 86.04%
# Val Loss: 0.3340, Val Acc: 88.24%
# Epoch 48/50:
# Train Loss: 0.3577, Train Acc: 86.18%
# Val Loss: 0.3405, Val Acc: 87.28%
# Epoch 49/50:
# Train Loss: 0.3557, Train Acc: 86.39%
# Val Loss: 0.3366, Val Acc: 86.95%
# Epoch 50/50:
# Train Loss: 0.3526, Train Acc: 86.70%
# Val Loss: 0.3321, Val Acc: 86.83%
# Classification Report:
#               precision    recall  f1-score   support
#
#       glioma       0.90      0.78      0.83       450
#   meningioma       0.73      0.75      0.74       400
#      notumor       0.95      0.98      0.96       536
#    pituitary       0.87      0.94      0.90       399
#
#     accuracy                           0.87      1785
#    macro avg       0.86      0.86      0.86      1785
# weighted avg       0.87      0.87      0.87      1785
# Loaded pretrained weights for efficientnet-b0
# C:\Users\viraj\AppData\Local\Temp\ipykernel_17084\466280177.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# Prediction Results:
# Predicted Class: meningioma
# Probabilities:
# glioma: 0.4813
# meningioma: 0.5175
# notumor: 0.0000
# pituitary: 0.0012

# %%
import torch
import torch.nn as nn
from torchvision import models, transforms
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# 2. Define image preprocessing
def preprocess_image(image_path):
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                           std=[0.229, 0.224, 0.225])
    ])
    
    image = Image.open(image_path).convert('RGB')
    image = transform(image).unsqueeze(0)  # Add batch dimension
    return image

# %%
# 3. Load the model
def load_model(model_path, num_classes=4):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = BrainTumorClassifier(num_classes)
    model.load_state_dict(torch.load(model_path))
    model.to(device)
    model.eval()
    return model, device

# %%
# 4. Predict function
def predict(model, image_tensor, device, class_names):
    image_tensor = image_tensor.to(device)
    with torch.no_grad():
        outputs = model(image_tensor)
        probabilities = torch.softmax(outputs, dim=1)
        predicted_class = torch.argmax(probabilities, dim=1)
    
    return predicted_class.item(), probabilities[0].cpu().numpy()

# %%
# 5. Visualize results
def show_prediction(image_path, predicted_class, probabilities, class_names):
    image = Image.open(image_path)
    plt.figure(figsize=(10, 5))
    
    # Show image
    plt.subplot(1, 2, 1)
    plt.imshow(image)
    plt.title(f'Predicted: {class_names[predicted_class]}')
    plt.axis('off')
    
    # Show probability distribution
    plt.subplot(1, 2, 2)
    plt.bar(class_names, probabilities)
    plt.title('Class Probabilities')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
# 6. Test single image
def test_single_image(model_path, image_path, class_names):
    # Load model
    model, device = load_model(model_path)
    
    # Preprocess image
    image_tensor = preprocess_image(image_path)
    
    # Make prediction
    predicted_class, probabilities = predict(model, image_tensor, device, class_names)
    
    # Show results
    show_prediction(image_path, predicted_class, probabilities, class_names)
    
    # Print detailed results
    print(f"\nPrediction Results:")
    print(f"Predicted Class: {class_names[predicted_class]}")
    print("Probabilities:")
    for name, prob in zip(class_names, probabilities):
        print(f"{name}: {prob:.4f}")

# %%
# 7. Test multiple images
def test_multiple_images(model_path, test_dir, class_names):
    model, device = load_model(model_path)
    
    correct = 0
    total = 0
    
    for class_name in class_names:
        class_dir = os.path.join(test_dir, class_name)
        if not os.path.exists(class_dir):
            continue
            
        for img_name in os.listdir(class_dir):
            img_path = os.path.join(class_dir, img_name)
            image_tensor = preprocess_image(img_path)
            
            predicted_class, probabilities = predict(model, image_tensor, device, class_names)
            
            true_class = class_names.index(class_name)
            if predicted_class == true_class:
                correct += 1
            total += 1
            
            print(f"\nImage: {img_name}")
            print(f"True Class: {class_name}")
            print(f"Predicted Class: {class_names[predicted_class]}")
            print(f"Confidence: {probabilities[predicted_class]:.4f}")
    
    accuracy = 100 * correct / total if total > 0 else 0
    print(f"\nTest Accuracy: {accuracy:.2f}% ({correct}/{total})")

# %%
# 8. Main execution
def main():
    # Define your parameters
    model_path = 'brain_tumor_classifier_efficient_net.pth'  # Path to your saved model
    class_names = ['glioma', 'meningioma', 'pituitary', 'no_tumor']  # Your classes
    
    # Choose testing mode
    test_mode = input("Enter 'single' to test one image or 'batch' to test multiple: ").lower()
    
    if test_mode == 'single':
        image_path = input("Enter the path to your test image: ")
        test_single_image(model_path, image_path, class_names)
    
    elif test_mode == 'batch':
        test_dir = input("Enter the path to your test directory: ")
        test_multiple_images(model_path, test_dir, class_names)
    
    else:
        print("Invalid mode selected. Please choose 'single' or 'batch'")

if __name__ == "__main__":
    main()
# Out:
# Loaded pretrained weights for efficientnet-b0
# C:\Users\viraj\AppData\Local\Temp\ipykernel_3172\446810812.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# Prediction Results:
# Predicted Class: pituitary
# Probabilities:
# glioma: 0.0195
# meningioma: 0.1525
# pituitary: 0.8139
# no_tumor: 0.0140

# %%
# 8. Main execution
def main():
    # Define your parameters
    model_path = 'brain_tumor_classifier_efficient_net.pth'  # Path to your saved model
    class_names = ['glioma', 'meningioma', 'pituitary', 'no_tumor']  # Your classes
    
    # Choose testing mode
    test_mode = input("Enter 'single' to test one image or 'batch' to test multiple: ").lower()
    
    if test_mode == 'single':
        image_path = input("Enter the path to your test image: ")
        test_single_image(model_path, image_path, class_names)
    
    elif test_mode == 'batch':
        test_dir = input("Enter the path to your test directory: ")
        test_multiple_images(model_path, test_dir, class_names)
    
    else:
        print("Invalid mode selected. Please choose 'single' or 'batch'")

if __name__ == "__main__":
    main()
# Out:
# Loaded pretrained weights for efficientnet-b0
# C:\Users\viraj\AppData\Local\Temp\ipykernel_3172\446810812.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# Image: 1864.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.8840
#
# Image: 1865.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9052
#
# Image: 1866.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.
jpg
# True Class: glioma
# Predicted Class: no_tumor
# Confidence: 0.5648
#
# Image: Tr-gl_0660.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9242
#
# Image: Tr-gl_0661.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.8683
#
# Image: Tr-gl_0662.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.7069
#
# Image: Tr-gl_0663.jpg
# True Class: glioma
# Predicted Class: meningioma
# Confidence: 0.4952
#
# Image: Tr-gl_0664.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.5295
#
# Image: Tr-gl_0665.jpg
# True Class: glioma
# Predicted Class: no_tumor
# Confidence: 0.6847
#
# Image: Tr-gl_0666.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.4698
#
# Image: Tr-gl_0667.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.8933
#
# Image: Tr-gl_0668.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9414
#
# Image: Tr-gl_0669.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.8608
#
# Image: Tr-gl_0670.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.8718
#
# Image: Tr-gl_0671.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.7632
#
# Image: Tr-gl_0672.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9625
#
# Image: Tr-gl_0673.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.7943
#
# Image: Tr-gl_0674.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9381
#
# Image: Tr-gl_0675.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.5808
#
# Image: Tr-gl_0676.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9926
#
# Image: Tr-gl_0677.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9532
#
# Image: Tr-gl_0678.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.7644
#
# Image: Tr-gl_0679.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9978
#
# Image: Tr-gl_0680.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9932
#
# Image: Tr-gl_0681.jpg
# True Class: glioma
# Predicted Class: no_tumor
# Confidence: 0.4776
#
# Image: Tr-gl_0682.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9847
#
# Image: Tr-gl_1091.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9393
#
# Image: Tr-gl_1092.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9798
#
# Image: Tr-gl_1093.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9742
#
# Image: Tr-gl_1094.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9392
#
# Image: Tr-gl_1095.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.8863
#
# Image: Tr-gl_1096.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9951
#
# Image: Tr-gl_1097.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9199
#
# Image: Tr-gl_1098.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.7430
#
# Image: Tr-gl_1099.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9805
#
# Image: Tr-gl_1100.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.7039
#
# Image: Tr-gl_1101.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9108
#
# Image: Tr-gl_1102.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9948
#
# Image: Tr-gl_1103.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9977
#
# Image: Tr-gl_1104.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9919
#
# Image: Tr-gl_1105.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9966
#
# Image: Tr-gl_1106.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9943
#
# Image: Tr-gl_1107.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.8284
#
# Image: Tr-gl_1108.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.8826
#
# Image: Tr-gl_1109.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9366
#
# Image: Tr-gl_1110.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.5380
#
# Image: Tr-gl_1111.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.8919
#
# Image: Tr-gl_1112.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9157
#
# Image: Tr-gl_1113.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.8244
#
# Image: Tr-gl_1114.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.6299
#
# Image: Tr-gl_1115.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9888
#
# Image: Tr-gl_1116.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.8840
#
# Image: Tr-gl_1117.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.6911
#
# Image: Tr-gl_1118.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.7278
#
# Image: Tr-gl_1119.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9483
#
# Image: Tr-gl_1120.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9559
#
# Image: Tr-gl_1121.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.8901
#
# Image: Tr-gl_1122.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9355
#
# Image: Tr-gl_1123.jpg
# True Class: glioma
# Predicted Class: no_tumor
# Confidence: 0.5324
#
# Image: Tr-gl_1124.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.8885
#
# Image: Tr-gl_1125.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9700
#
# Image: Tr-gl_1126.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9997
#
# Image: 100.jpg
# True Class: meningioma
# Predicted Class: glioma
# Confidence: 0.7800
#
# Image: 101.jpg
# True Class: meningioma
# Predicted Class: meningioma
# Confidence: 0.5847
#
# Image: 102.jpg
# True Class: meningioma
# Predicted Class: meningioma
# Confidence: 0.5899
#
# Image: 103.jpg
# True Class: meningioma
# Predicted Class: meningioma
# Confidence: 0.5674
#
# Image: 104.jpg
# True Class: meningioma
# Predicted Class: glioma
# Confidence: 0.5376
#
# Image: 105.jpg
# True Class: meningioma
# Predicted Class: meningioma
# Confidence: 0.6889
#
# Image: 106.jpg
# True Class: meningioma
# Predicted Class: meningioma
# Confidence: 0.6658
#
# Image: 107.jpg
# True Class: meningioma
# Predicted Class: meningioma
# Confidence: 0.7903
#
# Image: 108.jpg
# True Class: meningioma
# Predicted Class: meningioma
# Confidence: 0.7838
#
# Image: 109.jpg
# True Class: meningioma
# Predicted Class: meningioma
# Confidence: 0.6161
#
# Image: 232.jpg
# True Class: meningioma
# Predicted Class: meningioma
# Confidence: 0.5879
#
# Image: 233.jpg
# True Class: meningioma
# Predicted Class: meningioma
# Confidence: 0.5739
#
# Image: 234.jpg
# True Class: meningioma
# Predicted Class: meningioma
# Confidence: 0.6040
#
# Image: 235.jpg
# True Class: meningioma
# Predicted Class: meningioma
# Confidence: 0.6222
#
# Image: 236.jpg
# True Class: meningioma
# Predicted Class: glioma
# Confidence: 0.5647
#
# Image: 237.jpg
# True Class: meningioma
# Predicted Class: glioma
# Confidence: 0.4988
#
# Image: 238.jpg
# True Class: meningioma
# Predicted Class: glioma
# Confidence: 0.6497
#
# Image: 239.jpg
# True Class: meningioma
# Predicted Class: meningioma
# Confidence: 0.6829
#
# Image: 240.jpg
# True Class: meningioma
# Predicted Class: meningioma
# Confidence: 0.5899
#
# Image: 241.jpg
# True Class: meningioma
# Predicted Class: meningioma
# Confidence: 0.7125
#
# Image: 242.jpg
# True Class: meningioma
# Predicted Class: meningioma
# Confidence: 0.6366
#
# Image: 243.jpg
# True Class: meningioma
# Predicted Class: glioma
# Confidence: 0.6011
#
# Image: 244.jpg
# True Class: meningioma
# Predicted Class: glioma
# Confidence: 0.5518
#
# Image: 245.jpg
# True Class: meningioma
# Predicted Class: meningioma
# Confidence: 0.7038
#
# Image: 246.jpg
# True Class: meningioma
# Predicted Class: glioma
# Confidence: 0.4571
#
# Image: 247.jpg
# True Class: meningioma
# Predicted Class: no_tumor
# Confidence: 0.4239
#
# Image: 248.jpg
# True Class: meningioma
# Predicted Class: glioma
# Confidence: 0.3390
#
# Image: 249.jpg
# True Class: meningioma
# Predicted Class: no_tumor
# Confidence: 0.5796
#
# Image: 250.jpg
# True Class: meningioma
# Predicted Class: glioma
# Confidence: 0.