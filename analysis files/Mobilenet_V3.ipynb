# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import torchvision
from torchvision import transforms, datasets
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import os
from torch.amp import autocast, GradScaler

# %%
# Check for GPU availability
print(torch.cuda.is_available())  # Should return True
print(torch.cuda.current_device())  # Should return 0
print(torch.cuda.get_device_name(0))  # Should print "NVIDIA GeForce RTX 3050 Laptop GPU"

# Define constants
IMG_HEIGHT = 224  # MobileNetV3 default input size
IMG_WIDTH = 224   # MobileNetV3 default input size
BATCH_SIZE = 16   # Adjusted for MobileNetV3's efficiency, monitor memory
EPOCHS = 50
NUM_CLASSES = 4   # Matches your 4 classes
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# True
# 0
# NVIDIA GeForce RTX 3050 Laptop GPU

# %%
# Define the model with MobileNetV3-Large
class BrainTumorClassifier(nn.Module):
    def __init__(self, num_classes):
        super(BrainTumorClassifier, self).__init__()
        # Load MobileNetV3-Large with pretrained weights
        self.base_model = torchvision.models.mobilenet_v3_large(weights=torchvision.models.MobileNet_V3_Large_Weights.IMAGENET1K_V1)
        # Freeze base model parameters
        for param in self.base_model.parameters():
            param.requires_grad = False
        # Correct num_features for MobileNetV3-Large (960 after avgpool)
        num_features = self.base_model.classifier[0].in_features  # Should be 960
        # Replace the classifier
        self.base_model.classifier = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(num_features, 128),  # Match input to 960
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )
    
    def forward(self, x):
        return self.base_model(x)

# %%
# Data preprocessing and augmentation
def create_data_loaders(train_dir, val_dir):
    train_transforms = transforms.Compose([
        transforms.Resize((IMG_HEIGHT, IMG_WIDTH)),
        transforms.RandomRotation(20),
        transforms.RandomHorizontalFlip(),
        transforms.RandomAffine(degrees=0, translate=(0.2, 0.2)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    val_transforms = transforms.Compose([
        transforms.Resize((IMG_HEIGHT, IMG_WIDTH)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    train_dataset = datasets.ImageFolder(train_dir, transform=train_transforms)
    val_dataset = datasets.ImageFolder(val_dir, transform=val_transforms)
    
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
    
    return train_loader, val_loader, train_dataset.classes

# %%
# Training function with mixed precision
def train_model(model, train_loader, val_loader):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    scaler = GradScaler('cuda')
    
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}
    
    for epoch in range(EPOCHS):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()
            
            with autocast('cuda'):
                outputs = model(inputs)
                loss = criterion(outputs, labels)
            
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        
        train_loss = running_loss / len(train_loader)
        train_acc = 100 * correct / total
        
        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0
        
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
                with autocast('cuda'):
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        
        val_loss = val_loss / len(val_loader)
        val_acc = 100 * correct / total
        
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)
        
        print(f'Epoch {epoch+1}/{EPOCHS}:')
        print(f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%')
        print(f'Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%')
    
    return history

# %%
# Plotting function
def plot_training_history(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    ax1.plot(history['train_acc'], label='Training Accuracy')
    ax1.plot(history['val_acc'], label='Validation Accuracy')
    ax1.set_title('Model Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy (%)')
    ax1.legend()
    
    ax2.plot(history['train_loss'], label='Training Loss')
    ax2.plot(history['val_loss'], label='Validation Loss')
    ax2.set_title('Model Loss')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend()
    
    plt.tight_layout()
    plt.show()

# %%
# Evaluation function
def evaluate_model(model, val_loader, class_names):
    model.eval()
    y_true = []
    y_pred = []
    
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            with autocast('cuda'):
                outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())
    
    print("\nClassification Report:")
    print(classification_report(y_true, y_pred, target_names=class_names))
    
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

# %%
# Test a single image
def test_single_image(model_path, image_path, class_names):
    model = BrainTumorClassifier(num_classes=NUM_CLASSES)
    model.load_state_dict(torch.load(model_path))
    model.to(DEVICE)
    model.eval()

    transform = transforms.Compose([
        transforms.Resize((IMG_HEIGHT, IMG_WIDTH)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    from PIL import Image
    image = Image.open(image_path).convert('RGB')
    image = transform(image).unsqueeze(0).to(DEVICE)

    with torch.no_grad():
        with autocast('cuda'):
            output = model(image)
        probabilities = torch.softmax(output, dim=1)[0]
        predicted_class = torch.argmax(probabilities).item()

    print("\nPrediction Results:")
    print(f"Predicted Class: {class_names[predicted_class]}")
    print("Probabilities:")
    for i, prob in enumerate(probabilities):
        print(f"{class_names[i]}: {prob:.4f}")

# %%
# Test multiple images
def test_multiple_images(model_path, test_dir, class_names):
    model = BrainTumorClassifier(num_classes=NUM_CLASSES)
    model.load_state_dict(torch.load(model_path))
    model.to(DEVICE)
    model.eval()

    test_loader, _, _ = create_data_loaders(test_dir, test_dir)
    evaluate_model(model, test_loader, class_names)

# %%
# Main execution
def main():
    # Define paths (update these to your actual dataset paths)
    train_dir = "C:/Users/viraj/Documents/Virajs Projects/BT DETECTION/Training"  # Replace with your actual path
    val_dir = "C:/Users/viraj/Documents/Virajs Projects/BT DETECTION/Testing"     # Replace with your actual path
    model_path = 'V3_brain_tumor_classifier.pth'
    class_names = ['glioma', 'meningioma', 'pituitary', 'no_tumor']

    # Create data loaders
    train_loader, val_loader, class_names = create_data_loaders(train_dir, val_dir)

    # Initialize and train the model
    model = BrainTumorClassifier(num_classes=NUM_CLASSES)
    model.to(DEVICE)
    print(f"Using device: {DEVICE}")
    history = train_model(model, train_loader, val_loader)

    # Save the model
    torch.save(model.state_dict(), model_path)

    # Plot training history
    plot_training_history(history)

    # Evaluate the model
    evaluate_model(model, val_loader, class_names)

    # Testing mode
    test_mode = input("Enter 'single' to test one image or 'batch' to test multiple: ").lower()
    if test_mode == 'single':
        image_path = input("Enter the path to your test image: ")
        test_single_image(model_path, image_path, class_names)
    elif test_mode == 'batch':
        test_dir = input("Enter the path to your test directory: ")
        test_multiple_images(model_path, test_dir, class_names)
    else:
        print("Invalid mode selected. Please choose 'single' or 'batch'")

if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
# Epoch 1/50:
# Train Loss: 0.5940, Train Acc: 76.67%
# Val Loss: 0.5535, Val Acc: 77.65%
# Epoch 2/50:
# Train Loss: 0.4841, Train Acc: 81.34%
# Val Loss: 0.4636, Val Acc: 81.01%
# Epoch 3/50:
# Train Loss: 0.4590, Train Acc: 82.15%
# Val Loss: 0.4692, Val Acc: 80.22%
# Epoch 4/50:
# Train Loss: 0.4499, Train Acc: 82.39%
# Val Loss: 0.4641, Val Acc: 80.56%
# Epoch 5/50:
# Train Loss: 0.4412, Train Acc: 82.66%
# Val Loss: 0.4258, Val Acc: 80.78%
# Epoch 6/50:
# Train Loss: 0.4350, Train Acc: 82.94%
# Val Loss: 0.4488, Val Acc: 80.56%
# Epoch 7/50:
# Train Loss: 0.4313, Train Acc: 83.12%
# Val Loss: 0.4354, Val Acc: 81.68%
# Epoch 33/50:
# Train Loss: 0.3777, Train Acc: 85.29%
# Val Loss: 0.3757, Val Acc: 85.32%
# Epoch 34/50:
# Train Loss: 0.3706, Train Acc: 85.76%
# Val Loss: 0.3728, Val Acc: 84.59%
# Epoch 35/50:
# Train Loss: 0.3755, Train Acc: 85.57%
# Val Loss: 0.3677, Val Acc: 85.27%
# Epoch 36/50:
# Train Loss: 0.3795, Train Acc: 85.08%
# Val Loss: 0.3496, Val Acc: 85.55%
# Epoch 37/50:
# Train Loss: 0.3782, Train Acc: 85.47%
# Val Loss: 0.3612, Val Acc: 85.27%
# Epoch 38/50:
# Train Loss: 0.3742, Train Acc: 85.37%
# Val Loss: 0.3795, Val Acc: 85.10%
# Epoch 39/50:
# Train Loss: 0.3791, Train Acc: 85.28%
# Val Loss: 0.3498, Val Acc: 86.33%
# Epoch 40/50:
# Train Loss: 0.3741, Train Acc: 85.45%
# Val Loss: 0.3585, Val Acc: 86.05%
# Epoch 41/50:
# Train Loss: 0.3740, Train Acc: 85.21%
# Val Loss: 0.3673, Val Acc: 86.05%
# Epoch 42/50:
# Train Loss: 0.3729, Train Acc: 85.48%
# Val Loss: 0.3718, Val Acc: 84.93%
# Epoch 43/50:
# Train Loss: 0.3756, Train Acc: 85.47%
# Val Loss: 0.3651, Val Acc: 85.27%
# Epoch 44/50:
# Train Loss: 0.3730, Train Acc: 85.46%
# Val Loss: 0.3606, Val Acc: 85.55%
# Epoch 45/50:
# Train Loss: 0.3723, Train Acc: 85.51%
# Val Loss: 0.3487, Val Acc: 85.60%
# Epoch 46/50:
# Train Loss: 0.3740, Train Acc: 85.51%
# Val Loss: 0.3393, Val Acc: 86.83%
# Epoch 47/50:
# Train Loss: 0.3708, Train Acc: 85.77%
# Val Loss: 0.3270, Val Acc: 87.17%
# Epoch 48/50:
# Train Loss: 0.3630, Train Acc: 85.48%
# Val Loss: 0.3637, Val Acc: 85.94%
# Epoch 49/50:
# Train Loss: 0.3781, Train Acc: 85.28%
# Val Loss: 0.3529, Val Acc: 85.32%
# Epoch 50/50:
# Train Loss: 0.3751, Train Acc: 85.05%
# Val Loss: 0.3842, Val Acc: 85.04%
# Classification Report:
#               precision    recall  f1-score   support
#
#       glioma       0.87      0.79      0.83       450
#   meningioma       0.72      0.65      0.68       400
#      notumor       0.94      0.99      0.96       536
#    pituitary       0.82      0.94      0.88       399
#
#     accuracy                           0.85      1785
#    macro avg       0.84      0.84      0.84      1785
# weighted avg       0.85      0.85      0.85      1785
# C:\Users\viraj\AppData\Local\Temp\ipykernel_35520\3310675496.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# Prediction Results:
# Predicted Class: meningioma
# Probabilities:
# glioma: 0.1715
# meningioma: 0.8281
# notumor: 0.0000
# pituitary: 0.0004

# %%
import torch
import torch.nn as nn
from torchvision import models, transforms
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# 2. Define image preprocessing
def preprocess_image(image_path):
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                           std=[0.229, 0.224, 0.225])
    ])
    
    image = Image.open(image_path).convert('RGB')
    image = transform(image).unsqueeze(0)  # Add batch dimension
    return image

# %%
# 3. Load the model
def load_model(model_path, num_classes=4):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = BrainTumorClassifier(num_classes)
    model.load_state_dict(torch.load(model_path))
    model.to(device)
    model.eval()
    return model, device

# %%
# 4. Predict function
def predict(model, image_tensor, device, class_names):
    image_tensor = image_tensor.to(device)
    with torch.no_grad():
        outputs = model(image_tensor)
        probabilities = torch.softmax(outputs, dim=1)
        predicted_class = torch.argmax(probabilities, dim=1)
    
    return predicted_class.item(), probabilities[0].cpu().numpy()

# %%
# 5. Visualize results
def show_prediction(image_path, predicted_class, probabilities, class_names):
    image = Image.open(image_path)
    plt.figure(figsize=(10, 5))
    
    # Show image
    plt.subplot(1, 2, 1)
    plt.imshow(image)
    plt.title(f'Predicted: {class_names[predicted_class]}')
    plt.axis('off')
    
    # Show probability distribution
    plt.subplot(1, 2, 2)
    plt.bar(class_names, probabilities)
    plt.title('Class Probabilities')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
# 6. Test single image
def test_single_image(model_path, image_path, class_names):
    # Load model
    model, device = load_model(model_path)
    
    # Preprocess image
    image_tensor = preprocess_image(image_path)
    
    # Make prediction
    predicted_class, probabilities = predict(model, image_tensor, device, class_names)
    
    # Show results
    show_prediction(image_path, predicted_class, probabilities, class_names)
    
    # Print detailed results
    print(f"\nPrediction Results:")
    print(f"Predicted Class: {class_names[predicted_class]}")
    print("Probabilities:")
    for name, prob in zip(class_names, probabilities):
        print(f"{name}: {prob:.4f}")

# %%
# 7. Test multiple images
def test_multiple_images(model_path, test_dir, class_names):
    model, device = load_model(model_path)
    
    correct = 0
    total = 0
    
    for class_name in class_names:
        class_dir = os.path.join(test_dir, class_name)
        if not os.path.exists(class_dir):
            continue
            
        for img_name in os.listdir(class_dir):
            img_path = os.path.join(class_dir, img_name)
            image_tensor = preprocess_image(img_path)
            
            predicted_class, probabilities = predict(model, image_tensor, device, class_names)
            
            true_class = class_names.index(class_name)
            if predicted_class == true_class:
                correct += 1
            total += 1
            
            print(f"\nImage: {img_name}")
            print(f"True Class: {class_name}")
            print(f"Predicted Class: {class_names[predicted_class]}")
            print(f"Confidence: {probabilities[predicted_class]:.4f}")
    
    accuracy = 100 * correct / total if total > 0 else 0
    print(f"\nTest Accuracy: {accuracy:.2f}% ({correct}/{total})")

# %%
# 8. Main execution
def main():
    # Define your parameters
    model_path = 'V3_brain_tumor_classifier.pth'  # Path to your saved model
    class_names = ['glioma', 'meningioma', 'pituitary', 'no_tumor']  # Your classes
    
    # Choose testing mode
    test_mode = input("Enter 'single' to test one image or 'batch' to test multiple: ").lower()
    
    if test_mode == 'single':
        image_path = input("Enter the path to your test image: ")
        test_single_image(model_path, image_path, class_names)
    
    elif test_mode == 'batch':
        test_dir = input("Enter the path to your test directory: ")
        test_multiple_images(model_path, test_dir, class_names)
    
    else:
        print("Invalid mode selected. Please choose 'single' or 'batch'")

if __name__ == "__main__":
    main()
# Out:
# C:\Users\viraj\AppData\Local\Temp\ipykernel_35520\446810812.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# Prediction Results:
# Predicted Class: pituitary
# Probabilities:
# glioma: 0.0012
# meningioma: 0.0159
# pituitary: 0.9829
# no_tumor: 0.0001

# %%
# 8. Main execution
def main():
    # Define your parameters
    model_path = 'V3_brain_tumor_classifier.pth'  # Path to your saved model
    class_names = ['glioma', 'meningioma', 'pituitary', 'no_tumor']  # Your classes
    
    # Choose testing mode
    test_mode = input("Enter 'single' to test one image or 'batch' to test multiple: ").lower()
    
    if test_mode == 'single':
        image_path = input("Enter the path to your test image: ")
        test_single_image(model_path, image_path, class_names)
    
    elif test_mode == 'batch':
        test_dir = input("Enter the path to your test directory: ")
        test_multiple_images(model_path, test_dir, class_names)
    
    else:
        print("Invalid mode selected. Please choose 'single' or 'batch'")

if __name__ == "__main__":
    main()
# Out:
# C:\Users\viraj\AppData\Local\Temp\ipykernel_35520\446810812.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# Image: 1864.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.6584
#
# Image: 1865.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.8861
#
# Image: 1866.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.7102
#
# Image: 1867.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.7591
#
# Image: 1868.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.5316
#
# Image: 1869.jpg
# True Class: glioma
# Predicted Class: meningioma
# Confidence: 0.8643
#
# Image: 1870.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9686
#
# Image: 1871.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.5893
#
# Image: 1872.jpg
# True Class: glioma
# Predicted Class: meningioma
# Confidence: 0.7284
#
# Image: 1873.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.8255
#
# Image: 1874.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.8860
#
# Image: 1875.jpg
# True Class: glioma
# Predicted Class: meningioma
# Confidence: 0.5495
#
# Image: 1876.jpg
# True Class: glioma
# Predicted Class: meningioma
# Confidence: 0.5277
#
# Image: 1877.jpg
# True Class: glioma
# Predicted Class: meningioma
# Confidence: 0.8852
#
# Image: 1878.jpg
# True Class: glioma
# Predicted Class: meningioma
# Confidence: 0.9188
#
# Image: 1879.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9968
#
# Image: 1880.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9527
#
# Image: 1881.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.7708
#
# Image: 1882.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.5230
#
# Image: 1883.jpg
# True Class: glioma
# Predicted Class: meningioma
# Confidence: 0.6823
#
# Image: 1884.jpg
# True Class: glioma
# Predicted Class: meningioma
# Confidence: 0.7192
#
# Image: 1885.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9548
#
# Image: 1886.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.8781
#
# Image: 1887.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9898
#
# Image: 2404.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9374
#
# Image: 2405.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9885
#
# Image: 2406.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9965
#
# Image: 2407.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9971
#
# Image: 2408.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9961
#
# Image: 2409.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9974
#
# Image: 2410.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9720
#
# Image: 2411.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9036
#
# Image: 2412.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9598
#
# Image: 2413.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9961
#
# Image: 2414.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.8006
#
# Image: 2415.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9970
#
# Image: 2416.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9966
#
# Image: 2417.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9637
#
# Image: 2418.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9716
#
# Image: 2419.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9707
#
# Image: 2420.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9990
#
# Image: 2421.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9852
#
# Image: 2422.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9920
#
# Image: 2423.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.8363
#
# Image: 2424.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9757
#
# Image: 2425.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9752
#
# Image: 2426.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9816
#
# Image: 2427.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9938
#
# Image: 2428.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9981
#
# Image: 2429.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9983
#
# Image: 2430.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.7756
#
# Image: 2431.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.6736
#
# Image: 2432.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.7349
#
# Image: 2433.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.8724
#
# Image: 2434.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9703
#
# Image: 2435.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.5210
#
# Image: 2436.jpg
# True Class: glioma
# Predicted Class: meningioma
# Confidence: 0.6656
#
# Image: 2437.jpg
# True Class: glioma
# Predicted Class: meningioma
# Confidence: 0.6278
#
# Image: 2438.jpg
# True Class: glioma
# Predicted Class: meningioma
# Confidence: 0.7463
#
# Image: 2439.jpg
# True Class: glioma
# Predicted Class: meningioma
# Confidence: 0.7279
#
# Image: 2752.jpg
# True Class: glioma
# Predicted Class: meningioma
# Confidence: 0.6227
#
# Image: 2753.jpg
# True Class: glioma
# Predicted Class: no_tumor
# Confidence: 0.6308
#
# Image: 2754.jpg
# True Class: glioma
# Predicted Class: meningioma
# Confidence: 0.4767
#
# Image: 2755.jpg
# True Class: glioma
# Predicted Class: meningioma
# Confidence: 0.4981
#
# Image: 2756.jpg
# True Class: glioma
# Predicted Class: meningioma
# Confidence: 0.5105
#
# Image: 2757.jpg
# True Class: glioma
# Predicted Class: meningioma
# Confidence: 0.5212
#
# Image: 2758.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.7859
#
# Image: 2759.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9558
#
# Image: 2760.jpg
# True Class: glioma
# Predicted Class: no_tumor
# Confidence: 0.4106
#
# Image: 2761.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.8844
#
# Image: 2762.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.6109
#
# Image: 2763.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.7461
#
# Image: 2764.jpg
# True Class: glioma
# Predicted Class: no_tumor
# Confidence: 0.5217
#
# Image: 2765.jpg
# True Class: glioma
# Predicted Class: no_tumor
# Confidence: 0.5198
#
# Image: 2766.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.5471
#
# Image: 2767.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.6014
#
# Image: 2768.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9298
#
# Image: 2769.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9308
#
# Image: 2770.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9311
#
# Image: 2771.jpg
# True Class: glioma
# Predicted Class: meningioma
# Confidence: 0.5859
#
# Image: 2772.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.7217
#
# Image: 2773.jpg
# True Class: glioma
# Predicted Class: meningioma
# Confidence: 0.7116
#
# Image: 2774.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9846
#
# Image: 2775.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.9623
#
# Image: 2776.jpg
# True Class: glioma
# Predicted Class: glioma
# Confidence: 0.